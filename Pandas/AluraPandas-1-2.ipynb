# %% [markdown]
# # Relatório de análise 1

# %% [markdown]
# ## Importing Data Frame

# %%
import pandas as pd
import time

# %%
dados = pd.read_csv('Dados/aluguel.csv', sep =';')

# %% [markdown]
# ## Informações gerais sobre a base de Dados

# %% [markdown]
# [Aula 2 - parte 4](https://cursos.alura.com.br/course/introducao-python-pandas/task/40982)

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos de variáveis'])
tipos_de_dados.columns.name = 'Variáveis'

# %%
tipos_de_dados
# Out:
# Variáveis  Tipos de variáveis
# Tipo                   object
# Bairro                 object
# Quartos                 int64
# Vagas                   int64
# Suites                  int64
# Area                    int64
# Valor                 float64
# Condominio            float64
# IPTU                  float64

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados.shape[1]
# Out:
# 9

# %%
print("A base de dados apresenta {} registros (imóveis) e {} variáveis".format(dados.shape[0],dados.shape[1]))
# Out:
# A base de dados apresenta 32960 registros (imóveis) e 9 variáveis

# %% [markdown]
# # Aula extra
#
# [Extras da aula - 02](https://cursos.alura.com.br/course/introducao-python-pandas/task/40983)

# %%
import pandas as pd

# %%
json = open('extras/aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_json = pd.read_json('extras/aluguel.json')
df_json
# Out:
#    Area           Bairro  Condominio    IPTU  Quartos  Suites  \
# 0    40       Copacabana       500.0    60.0        1       0
# 1   100  Jardim Botânico         NaN     NaN        2       1
# 2   150  Barra da Tijuca      4020.0  1111.0        0       0
# 3    15           Centro       390.0    20.0        1       0
# 4    48     Higienópolis       230.0     NaN        1       0
# 5    70     Vista Alegre         NaN     NaN        3       0
# 6    50         Cachambi       301.0    17.0        2       0
# 7   750  Barra da Tijuca         NaN     NaN        5       5
# 8    65            Ramos         NaN     NaN        2       0
# 9   695           Centro     19193.0  3030.0        0       0
#
#                       Tipo  Vagas  Valor
# 0                Quitinete      0   1700
# 1                     Casa      0   7000
# 2  Conjunto Comercial/Sala      4   5200
# 3              Apartamento      0    800
# 4              Apartamento      0    800
# ...

# %% [markdown]
# ### Need to install xlrd to work with excel files
#
# pip install xlrd

# %%
df_xlsx = pd.read_excel('extras/aluguel.xlsx')
df_xlsx
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# ### You can take Data frames directly from html sites
#
# I made a test and works successfully. I create an google sheets file. In the share settings I let public to anyone with the link. I had to install html5lib and bs4 (Beautiful soup) libraries, but worked. Pandas was able to go on my Gsheets and take all the contents on the page. But pandas take all of rows and collumns, even if it's empty. I'll figure out how to work with that.
#
# pip install html5lib bs4
#
# The number between [-] means wich one of the Df's we want to acess
#
# [Google Sheets File](https://docs.google.com/spreadsheets/d/1VvXMjWuF8M67xHxIp_wG-pEyPdT_3XOdG8YPc_daWiA/edit#gid=0)

# %%
len(df_html)
# Out:
# 2

# %%
df_html = pd.read_html('https://docs.google.com/spreadsheets/d/1VvXMjWuF8M67xHxIp_wG-pEyPdT_3XOdG8YPc_daWiA/edit?usp=sharing')
df_html[0].head(11)
# Out:
#     Unnamed: 0   A   B      C        D         E          F             G  \
# 0            1 NaN NaN    NaN      NaN       NaN        NaN           NaN
# 1            2 NaN NaN  Teste  Teste 1  Teste 13  Teste 133  Teste 131559
# 2            3 NaN NaN      0     1556        50        646          6652
# 3            4 NaN NaN      1     1557        51        647          6653
# 4            5 NaN NaN      2     1558        52        648          6654
# 5            6 NaN NaN      3     1559        53        649          6655
# 6            7 NaN NaN      4     1560        54        650          6656
# 7            8 NaN NaN      5     1561        55        651          6657
# 8            9 NaN NaN      6     1562        56        652          6658
# 9           10 NaN NaN      7     1563        57        653          6659
# 10          11 NaN NaN      8     1564        58        654          6660
#
#              H            I ...   Q   R   S   T   U   V   W   X   Y   Z
# ...
